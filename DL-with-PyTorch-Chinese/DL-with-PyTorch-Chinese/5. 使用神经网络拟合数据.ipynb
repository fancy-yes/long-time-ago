# %% [markdown]
# - 使用非线性激活函数作为与线性模型的关键区别
# - 介绍常用的激活函数
# - 介绍包含神经网络构件的PyTorch的nn模块
# - 用神经网络解决简单的线性拟合问题

# %% [markdown]
# 不管具体模型是什么，参数的更新方式都是一样的：反向传播误差然后通过计算损失关于参数的梯度来更新这些参数。
#
# 只要模型是可微的，PyTorch就能够自动计算梯度，训练循环代码将照常工作。
#
# 如下图：

# %% [markdown]
# 学习过程的抽象模型
# ![image.png](attachment:2957b488-2730-4079-b75a-0458f67a0359.png)

# %% [markdown]
# ---

# %% [markdown]
# ###  目前，我们可以更改模型架构，实现一个完整的人工神经网络来解决问题
